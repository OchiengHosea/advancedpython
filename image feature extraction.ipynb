# %%
import cv2

# %%
imagepath = 'data/dog.jpg'

image = cv2.imread(imagepath)

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

plt.imshow(image)

# %%
image.shape
# Out:
# (130, 173, 3)

# %%
size = (32, 32)
resized_image_feature_vector = cv2.resize(image, size)

# %%
resized_image_feature_vector
# Out:
# array([[[244, 237, 228],
#         [251, 254, 253],
#         [255, 250, 242],
#         ...,
#         [253, 247, 242],
#         [255, 245, 238],
#         [254, 243, 236]],
#
#        [[126, 118, 108],
#         [237, 218, 211],
#         [166, 156, 144],
#         ...,
#         [255, 246, 242],
#         [255, 245, 241],
#         [254, 241, 233]],
#
#        [[254, 253, 251],
#         [255, 254, 252],
#         [254, 253, 251],
#         ...,
#         [250, 239, 230],
#         [243, 224, 214],
#         [190, 177, 165]],
#
#        ...,
#
#        [[206, 206, 210],
#         [208, 209, 213],
#         [207, 208, 212],
#         ...,
#         [119, 131, 138],
#         [121, 135, 141],
#         [115, 129, 136]],
#
#        [[207, 208, 211],
#         [211, 209, 212],
#         [213, 211, 214],
#         ...,
#         [110, 124, 130],
#         [104, 118, 124],
#         [107, 121, 127]],
#
#        [[202, 204, 206],
#         [211, 210, 213],
#         [211, 209, 211],
#         ...,
#         [119, 132, 137],
#         [100, 113, 118],
#         [ 99, 112, 118]]], dtype=uint8)

# %%
plt.imshow(resized_image_feature_vector)

# %%
resized_flattened = resized_image_feature_vector.flatten()
resized_flattened
# Out:
# array([244, 237, 228, ...,  99, 112, 118], dtype=uint8)
