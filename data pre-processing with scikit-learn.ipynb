# %%
import pandas as pd
from sklearn import preprocessing

# %%
print(pd.__version__)
# Out:
# 1.1.0

# %%
exam_data = pd.read_csv('data/exams.csv', quotechar='"')
exam_data
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group E          associate's degree      standard
# 1   female        group C          associate's degree  free/reduced
# 2     male        group D           bachelor's degree      standard
# 3   female        group A           bachelor's degree      standard
# 4   female        group D                 high school  free/reduced
# ..     ...            ...                         ...           ...
# 95  female        group A             master's degree  free/reduced
# 96  female        group D                 high school  free/reduced
# 97  female        group C                some college      standard
# 98    male        group D            some high school      standard
# 99  female        group A             master's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                completed          79             75             81
# 1                     none          56             65             64
# 2                     none          86             68             74
# 3                     none          68             78             76
# 4                     none          49             68             61
# ..                     ...         ...            ...            ...
# 95               completed          59             76             80
# 96                    none          60             62             61
# 97                    none          69             82             83
# 98                    none          89             83             79
# 99               completed          65             88             88
#
# [100 rows x 8 columns]

# %%
math_average = exam_data["math score"].mean()
reading_average = exam_data["reading score"].mean()
writing_average = exam_data["writing score"].mean()

print(f'Math Average {math_average}')
print(f'Reading Average {reading_average}')
print(f'Writing Average {writing_average}')
# Out:
# Math Average 65.06
# Reading Average 67.28
# Writing Average 66.47

# %%
# standardadization
exam_data[["math_score"]] = preprocessing.scale(exam_data[["math score"]])
exam_data[["reading_score"]] = preprocessing.scale(exam_data[["reading score"]])
exam_data[["writing_score"]] = preprocessing.scale(exam_data[["writing score"]])
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group E          associate's degree      standard
# 1   female        group C          associate's degree  free/reduced
# 2     male        group D           bachelor's degree      standard
# 3   female        group A           bachelor's degree      standard
# 4   female        group D                 high school  free/reduced
# ..     ...            ...                         ...           ...
# 95  female        group A             master's degree  free/reduced
# 96  female        group D                 high school  free/reduced
# 97  female        group C                some college      standard
# 98    male        group D            some high school      standard
# 99  female        group A             master's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score  \
# 0                completed          79             75             81
# 1                     none          56             65             64
# 2                     none          86             68             74
# 3                     none          68             78             76
# 4                     none          49             68             61
# ..                     ...         ...            ...            ...
# 95               completed          59             76             80
# 96                    none          60             62             61
# 97                    none          69             82             83
# 98                    none          89             83             79
# 99               completed          65             88             88
#
#     math_score  reading_score  writing_score
# 0     0.994557       0.574138       1.049901
# 1    -0.646391      -0.169564      -0.178476
# 2     1.493976       0.053547       0.544099
# 3     0.209756       0.797248       0.688613
# 4    -1.145810       0.053547      -0.395248
# ..         ...            ...            ...
# 95   -0.432354       0.648508       0.977643
# 96   -0.361008      -0.392675      -0.395248
# 97    0.281101       1.094729       1.194416
# 98    1.708013       1.169099       0.905386
# 99   -0.004281       1.540950       1.555703
#
# [100 rows x 11 columns]

# %%
le = preprocessing.LabelEncoder()
exam_data["gender"] = le.fit_transform(exam_data['gender'].astype(str))
exam_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0       1        group E          associate's degree      standard
# 1       0        group C          associate's degree  free/reduced
# 2       1        group D           bachelor's degree      standard
# 3       0        group A           bachelor's degree      standard
# 4       0        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          79             75             81
# 1                    none          56             65             64
# 2                    none          86             68             74
# 3                    none          68             78             76
# 4                    none          49             68             61
#
#    math_score  reading_score  writing_score
# 0    0.994557       0.574138       1.049901
# 1   -0.646391      -0.169564      -0.178476
# 2    1.493976       0.053547       0.544099
# 3    0.209756       0.797248       0.688613
# 4   -1.145810       0.053547      -0.395248

# %%
le.classes_
# Out:
# array(['0', '1'], dtype=object)

# %%
pd.get_dummies(exam_data['race/ethnicity'])
# Out:
#     group A  group B  group C  group D  group E
# 0         0        0        0        0        1
# 1         0        0        1        0        0
# 2         0        0        0        1        0
# 3         1        0        0        0        0
# 4         0        0        0        1        0
# ..      ...      ...      ...      ...      ...
# 95        1        0        0        0        0
# 96        0        0        0        1        0
# 97        0        0        1        0        0
# 98        0        0        0        1        0
# 99        1        0        0        0        0
#
# [100 rows x 5 columns]

# %%
exam_data = pd.get_dummies(exam_data, columns=['race/ethnicity'])

# %%
exam_data
# Out:
#     gender parental level of education         lunch test preparation course  \
# 0        1          associate's degree      standard               completed
# 1        0          associate's degree  free/reduced                    none
# 2        1           bachelor's degree      standard                    none
# 3        0           bachelor's degree      standard                    none
# 4        0                 high school  free/reduced                    none
# ..     ...                         ...           ...                     ...
# 95       0             master's degree  free/reduced               completed
# 96       0                 high school  free/reduced                    none
# 97       0                some college      standard                    none
# 98       1            some high school      standard                    none
# 99       0             master's degree  free/reduced               completed
#
#     math score  reading score  writing score  math_score  reading_score  \
# 0           79             75             81    0.994557       0.574138
# 1           56             65             64   -0.646391      -0.169564
# 2           86             68             74    1.493976       0.053547
# 3           68             78             76    0.209756       0.797248
# 4           49             68             61   -1.145810       0.053547
# ..         ...            ...            ...         ...            ...
# 95          59             76             80   -0.432354       0.648508
# 96          60             62             61   -0.361008      -0.392675
# 97          69             82             83    0.281101       1.094729
# 98          89             83             79    1.708013       1.169099
# 99          65             88             88   -0.004281       1.540950
#
#     writing_score  race/ethnicity_group A  race/ethnicity_group B  \
# 0        1.049901                       0                       0
# 1       -0.178476                       0                       0
# 2        0.544099                       0                       0
# 3        0.688613                       1                       0
# 4       -0.395248                       0                       0
# ..            ...                     ...                     ...
# 95       0.977643                       1                       0
# 96      -0.395248                       0                       0
# 97       1.194416                       0                       0
# 98       0.905386                       0                       0
# 99       1.555703                       1                       0
#
#     race/ethnicity_group C  race/ethnicity_group D  race/ethnicity_group E
# 0                        0                       0                       1
# 1                        1                       0                       0
# 2                        0                       1                       0
# 3                        0                       0                       0
# 4                        0                       1                       0
# ..                     ...                     ...                     ...
# 95                       0                       0                       0
# 96                       0                       1                       0
# 97                       1                       0                       0
# 98                       0                       1                       0
# 99                       0                       0                       0
#
# [100 rows x 15 columns]

# %%
exam_data = pd.get_dummies(exam_data, columns=['parental level of education', 'lunch', 'test preparation course'])
exam_data.head()
# Out:
#    gender  math score  reading score  writing score  math_score  \
# 0       1          79             75             81    0.994557
# 1       0          56             65             64   -0.646391
# 2       1          86             68             74    1.493976
# 3       0          68             78             76    0.209756
# 4       0          49             68             61   -1.145810
#
#    reading_score  writing_score  race/ethnicity_group A  \
# 0       0.574138       1.049901                       0
# 1      -0.169564      -0.178476                       0
# 2       0.053547       0.544099                       0
# 3       0.797248       0.688613                       1
# 4       0.053547      -0.395248                       0
#
#    race/ethnicity_group B  race/ethnicity_group C  ...  \
# 0                       0                       0  ...
# 1                       0                       1  ...
# 2                       0                       0  ...
# 3                       0                       0  ...
# 4                       0                       0  ...
#
#    parental level of education_associate's degree  \
# 0                                               1
# 1                                               1
# 2                                               0
# 3                                               0
# 4                                               0
#
#    parental level of education_bachelor's degree  \
# 0                                              0
# 1                                              0
# 2                                              1
# 3                                              1
# 4                                              0
#
#    parental level of education_high school  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        1
#
#    parental level of education_master's degree  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    parental level of education_some college  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#    parental level of education_some high school  lunch_free/reduced  \
# 0                                             0                   0
# 1                                             0                   1
# 2                                             0                   0
# 3                                             0                   0
# 4                                             0                   1
#
#    lunch_standard  test preparation course_completed  \
# 0               1                                  1
# 1               0                                  0
# 2               1                                  0
# 3               1                                  0
# 4               0                                  0
#
#    test preparation course_none
# 0                             0
# 1                             1
# 2                             1
# 3                             1
# 4                             1
#
# [5 rows x 22 columns]

# %%
# preprocessing text data
