# %%
# KNN - every sample has a lable
# A new value is compared to the existing elemnts 
# and the sample nearest to it is the most ikely to be decided on
# comparison is done using Euclidean distance, Hamming Distance, Manhattan Distance

# Distance measures
# Euclidean distance - measurres distance between 2 points in a continous space
# L1 - distance for discreet also called snake distance/block/manhattan
# -found by adding up abbsolute values of differences in the coordinates

import numpy as np
import tensorflow as tf

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("mnist_data/", one_hot=True)
training_digits, training_labels = mnist.train.next_batch(5000)
training_digits_pl = tf.placeholder("float", [None, 784])
test_digit_pl = tf.placeholder("float", [784])
# Out:
# Extracting mnist_data/train-images-idx3-ubyte.gz
# Extracting mnist_data/train-labels-idx1-ubyte.gz
# Extracting mnist_data/t10k-images-idx3-ubyte.gz
# Extracting mnist_data/t10k-labels-idx1-ubyte.gz

# %%
test_digits, test_labels = mnist.test.next_batch(200)
# Nearest neighbor calculation using L1 distance
l1_distance = tf.abs(tf.add(training_digits_pl, tf.negative(test_digit_pl)))
distance = tf.reduce_sum(l1_distance, axis=1)

# Prediction: get min distance index (Nearest Neighbor)
pred = tf.arg_min(distance, 0)

accuracy = 0.

# Initialize the variables
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    
    # loop over test data
    for i in range(len(test_digits)):
        nn_index = sess.run(pred, 
                               feed_dict={training_digits_pl: training_digits, test_digit_pl:test_digits[i, :]})
        print("Test,", i, "Prediction:", np.argmax(training_labels[nn_index]), 
             "True Lable:", np.argmax(test_labels[i]))
        
        if np.argmax(training_labels[nn_index]) == np.argmax(test_labels[i]):
            accuracy +=1./len(test_digits)
            
        print("Done!")
        print("Accuracy:", accuracy)
# Out:
# Test, 0 Prediction: 9 True Lable: 9
# Done!
# Accuracy: 0.005
# Test, 1 Prediction: 3 True Lable: 3
# Done!
# Accuracy: 0.01
# Test, 2 Prediction: 5 True Lable: 5
# Done!
# Accuracy: 0.015
# Test, 3 Prediction: 0 True Lable: 0
# Done!
# Accuracy: 0.02
# Test, 4 Prediction: 7 True Lable: 7
# Done!
# Accuracy: 0.025
# Test, 5 Prediction: 0 True Lable: 0
# Done!
# Accuracy: 0.030000000000000002
# Test, 6 Prediction: 7 True Lable: 9
# Done!
# Accuracy: 0.030000000000000002
# Test, 7 Prediction: 5 True Lable: 5
# Done!
# Accuracy: 0.035
# Test, 8 Prediction: 9 True Lable: 9
# Done!
# Accuracy: 0.04
# Test, 9 Prediction: 5 True Lable: 5
# Done!
# Accuracy: 0.045
# Test, 10 Prediction: 2 True Lable: 2
# Done!
# Accuracy: 0.049999999999999996
# Test, 11 Prediction: 2 True Lable: 2
# Done!
# Accuracy: 0.05499999999999999
# Test, 12 Prediction: 4 True Lable: 4
# Done!
# Accuracy: 0.05999999999999999
# Test, 13 Prediction: 6 True Lable: 6
# Done!
# Accuracy: 0.06499999999999999
# ...
